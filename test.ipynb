# %%
# %cd /content/drive/MyDrive/github/DL
# Out:
# /content/drive/MyDrive/github/DL

# %%
# !git config --global user.email jisy2718@gmail.com
# !git config --global user.name jisy2718

# %%
! git add .

# %%
! git commit -m "test"
# Out:
# [master (root-commit) 590d7c3] test
#  1 file changed, 1 insertion(+)
#  create mode 100644 test.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 998 bytes | 332.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/jisy2718/DL.git
#  * [new branch]      master -> master
